# %% [markdown]
# ## Contents
# #### 1. Import libraries
# #### 2. Exploring Data
# #### 3. Cleaning Data
# #### 4. Export cleaned data

# %% [markdown]
# ## 1. Import libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# create path 
path = r'C:\Users\Christian\Desktop\Mein Ordner\CF\Data Immersion\Achievement6\Achievement6-Project'

# %%
# import dataframe
df = pd.read_csv(os.path.join(path, 'Data', 'Original Data', 'Air_Traffic_Cargo_Statistics.csv'))

# %% [markdown]
# ## 2. Exploring Data

# %%
df.head()
# Out:
#    Activity Period Activity Period Start Date  \
# 0           199907                 01-07-1999
# 1           199907                 01-07-1999
# 2           199907                 01-07-1999
# 3           199907                 01-07-1999
# 4           199907                 01-07-1999
#
#                          Operating Airline Operating Airline IATA Code  \
# 0                             ATA Airlines                          TZ
# 1                             ATA Airlines                          TZ
# 2                             ATA Airlines                          TZ
# 3                             ATA Airlines                          TZ
# 4  Aeroflot Russian International Airlines                         NaN
#
#                          Published Airline Published Airline IATA Code  \
# 0                             ATA Airlines                          TZ
# 1                             ATA Airlines                          TZ
# 2                             ATA Airlines                          TZ
# 3                             ATA Airlines                          TZ
# 4  Aeroflot Russian International Airlines                         NaN
#
#      GEO Summary GEO Region Activity Type Code Cargo Type Code  \
# 0       Domestic         US           Deplaned           Cargo
# 1       Domestic         US           Deplaned            Mail
# 2       Domestic         US           Enplaned           Cargo
# 3       Domestic         US           Enplaned            Mail
# 4  International     Europe           Deplaned           Cargo
#
#   Cargo Aircraft Type  Cargo Weight LBS  Cargo Metric TONS        data_as_of  \
# 0           Passenger            349048         158.328173  20-11-2023 07:01
# 1           Passenger            122003          55.340561  20-11-2023 07:01
# 2           Passenger            514450         233.354520  20-11-2023 07:01
# 3           Passenger             89776          40.722394  20-11-2023 07:01
# 4           Passenger             13086           5.935810  20-11-2023 07:01
#
#      data_loaded_at
# 0  20-11-2023 07:02
# 1  20-11-2023 07:02
# 2  20-11-2023 07:02
# 3  20-11-2023 07:02
# 4  20-11-2023 07:02

# %%
df.describe()
# Out:
#        Activity Period  Cargo Weight LBS  Cargo Metric TONS
# count     53872.000000      5.387200e+04       53872.000000
# mean     201083.594353      5.192588e+05         235.535784
# std         703.928044      1.013786e+06         459.853292
# min      199907.000000      1.000000e+00           0.000454
# 25%      200502.000000      1.964350e+04           8.910292
# 50%      201101.000000      1.443325e+05          65.469222
# 75%      201706.000000      5.918928e+05         268.482551
# max      202309.000000      2.381234e+07       10801.278330

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53872 entries, 0 to 53871
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Activity Period              53872 non-null  int64
#  1   Activity Period Start Date   53872 non-null  object
#  2   Operating Airline            53872 non-null  object
#  3   Operating Airline IATA Code  53294 non-null  object
#  4   Published Airline            53872 non-null  object
#  5   Published Airline IATA Code  53294 non-null  object
#  6   GEO Summary                  53872 non-null  object
#  7   GEO Region                   53872 non-null  object
#  8   Activity Type Code           53872 non-null  object
#  9   Cargo Type Code              53872 non-null  object
#  10  Cargo Aircraft Type          53872 non-null  object
#  11  Cargo Weight LBS             53872 non-null  int64
#  12  Cargo Metric TONS            53872 non-null  float64
#  13  data_as_of                   53872 non-null  object
#  14  data_loaded_at               53872 non-null  object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 6.2+ MB

# %%
df.shape
# Out:
# (53872, 15)

# %% [markdown]
# ## 3. Cleaning Data

# %%
# change data type
df['Activity Period'] = df['Activity Period'].astype('str')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53872 entries, 0 to 53871
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Activity Period              53872 non-null  object
#  1   Activity Period Start Date   53872 non-null  object
#  2   Operating Airline            53872 non-null  object
#  3   Operating Airline IATA Code  53294 non-null  object
#  4   Published Airline            53872 non-null  object
#  5   Published Airline IATA Code  53294 non-null  object
#  6   GEO Summary                  53872 non-null  object
#  7   GEO Region                   53872 non-null  object
#  8   Activity Type Code           53872 non-null  object
#  9   Cargo Type Code              53872 non-null  object
#  10  Cargo Aircraft Type          53872 non-null  object
#  11  Cargo Weight LBS             53872 non-null  int64
#  12  Cargo Metric TONS            53872 non-null  float64
#  13  data_as_of                   53872 non-null  object
#  14  data_loaded_at               53872 non-null  object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 6.2+ MB

# %%
#rename columns
df.rename(columns = {'data_as_of' : 'last_update', 'data_loaded_at' : 'upload_date'}, inplace = True)

# %%
df.head()
# Out:
#   Activity Period Activity Period Start Date  \
# 0          199907                 01-07-1999
# 1          199907                 01-07-1999
# 2          199907                 01-07-1999
# 3          199907                 01-07-1999
# 4          199907                 01-07-1999
#
#                          Operating Airline Operating Airline IATA Code  \
# 0                             ATA Airlines                          TZ
# 1                             ATA Airlines                          TZ
# 2                             ATA Airlines                          TZ
# 3                             ATA Airlines                          TZ
# 4  Aeroflot Russian International Airlines                         NaN
#
#                          Published Airline Published Airline IATA Code  \
# 0                             ATA Airlines                          TZ
# 1                             ATA Airlines                          TZ
# 2                             ATA Airlines                          TZ
# 3                             ATA Airlines                          TZ
# 4  Aeroflot Russian International Airlines                         NaN
#
#      GEO Summary GEO Region Activity Type Code Cargo Type Code  \
# 0       Domestic         US           Deplaned           Cargo
# 1       Domestic         US           Deplaned            Mail
# 2       Domestic         US           Enplaned           Cargo
# 3       Domestic         US           Enplaned            Mail
# 4  International     Europe           Deplaned           Cargo
#
#   Cargo Aircraft Type  Cargo Weight LBS  Cargo Metric TONS       last_update  \
# 0           Passenger            349048         158.328173  20-11-2023 07:01
# 1           Passenger            122003          55.340561  20-11-2023 07:01
# 2           Passenger            514450         233.354520  20-11-2023 07:01
# 3           Passenger             89776          40.722394  20-11-2023 07:01
# 4           Passenger             13086           5.935810  20-11-2023 07:01
#
#         upload_date
# 0  20-11-2023 07:02
# 1  20-11-2023 07:02
# 2  20-11-2023 07:02
# 3  20-11-2023 07:02
# 4  20-11-2023 07:02

# %%
#check for missing values
df.isnull().sum()
# Out:
# Activity Period                  0
# Activity Period Start Date       0
# Operating Airline                0
# Operating Airline IATA Code    578
# Published Airline                0
# Published Airline IATA Code    578
# GEO Summary                      0
# GEO Region                       0
# Activity Type Code               0
# Cargo Type Code                  0
# Cargo Aircraft Type              0
# Cargo Weight LBS                 0
# Cargo Metric TONS                0
# last_update                      0
# upload_date                      0
# dtype: int64

# %%
df_miss = df[df['Operating Airline IATA Code'].isnull()]

# %%
df_miss.head()
# Out:
#    Activity Period Activity Period Start Date  \
# 4           199907                 01-07-1999
# 5           199907                 01-07-1999
# 44          199907                 01-07-1999
# 45          199907                 01-07-1999
# 62          199907                 01-07-1999
#
#                           Operating Airline Operating Airline IATA Code  \
# 4   Aeroflot Russian International Airlines                         NaN
# 5   Aeroflot Russian International Airlines                         NaN
# 44               Atlas Air, Inc. (inactive)                         NaN
# 45               Atlas Air, Inc. (inactive)                         NaN
# 62              China Eastern Airlines, Inc                         NaN
#
#                           Published Airline Published Airline IATA Code  \
# 4   Aeroflot Russian International Airlines                         NaN
# 5   Aeroflot Russian International Airlines                         NaN
# 44               Atlas Air, Inc. (inactive)                         NaN
# 45               Atlas Air, Inc. (inactive)                         NaN
# 62              China Eastern Airlines, Inc                         NaN
#
#       GEO Summary GEO Region Activity Type Code Cargo Type Code  \
# 4   International     Europe           Deplaned           Cargo
# 5   International     Europe           Enplaned           Cargo
# 44  International       Asia           Deplaned           Cargo
# 45  International       Asia           Enplaned           Cargo
# 62  International       Asia           Deplaned           Cargo
#
#    Cargo Aircraft Type  Cargo Weight LBS  Cargo Metric TONS       last_update  \
# 4            Passenger             13086           5.935810  20-11-2023 07:01
# 5            Passenger              1161           0.526630  20-11-2023 07:01
# 44           Freighter            705421         319.978966  20-11-2023 07:01
# 45           Freighter            522520         237.015072  20-11-2023 07:01
# 62           Passenger             69797          31.659919  20-11-2023 07:01
#
#          upload_date
# 4   20-11-2023 07:02
# 5   20-11-2023 07:02
# 44  20-11-2023 07:02
# 45  20-11-2023 07:02
# 62  20-11-2023 07:02

# %%
df_miss['Operating Airline'].value_counts()
# Out:
# Operating Airline
# DHL Express (USA)                          154
# Aeroflot Russian International Airlines    112
# Atlas Air, Inc. (inactive)                  63
# China Eastern Airlines, Inc                 62
# Emery Worldwide Airlines, Inc.              52
# Odyssey Transport                           22
# El Al Israel Airlines LTD.                  20
# Swissport USA                               17
# ASTAR USA, LLC                              16
# Air Italy S.P.A                             14
# Union Flights                               12
# Norwegian Air Shuttle ASA                    8
# Polar Air Cargo                              7
# Air Transport International, LLC.            6
# Total Airport Services, Inc. (Inactive)      6
# Focus Air                                    2
# Dubai Air Wing                               2
# E.A.G.L.E.                                   1
# All Canada Express                           1
# Express.net Airlines                         1
# Name: count, dtype: int64

# %%
# check for duplicates 
df_dups = df[df.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [Activity Period, Activity Period Start Date, Operating Airline, Operating Airline IATA Code, Published Airline, Published Airline IATA Code, GEO Summary, GEO Region, Activity Type Code, Cargo Type Code, Cargo Aircraft Type, Cargo Weight LBS, Cargo Metric TONS, last_update, upload_date]
# Index: []

# %% [markdown]
# ### No duplicates found

# %% [markdown]
# ## 4. Export cleaned data

# %%
df.to_pickle(os.path.join(path, 'Data', 'Prepared Data', 'Air_Traffic_Cargo_Statistics_cleaned.pkl'))
